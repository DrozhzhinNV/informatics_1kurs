# %% [markdown]
# Федя Лягушонков сидит на камне посреди озера. Внезапно он замечает Фаню Лягушонкову, которая сидит на другом камне. Федя хочет добраться до Фани, но так как вода грязная, он
# хочет избежать попадания в воду и добраться до нее, прыгая по камушкам.
# Чтобы выполнить заданную последовательность прыжков, длина одного прыжка лягушки, очевидно, должна не меньше длины самого длинного прыжка в последовательности.
# Лягушачье расстояние (frog distance, или минимаксное расстояние) между двумя камнями определяется как
# минимальная длина прыжка среди всех возможных путей (последовательностей прыжков) между двумя камнями.
# На вход даются координаты камня Феди, камня Фани и всех других камней в озере.
# Вычислите минимаксное расстояние между камнями Феди и Фани.
#
# Формат ввода:
# * в первой строке указано N - количество камней в озере
# * далее идут N строк с координатами камней. Первый камень в списке - камень Феди, второй - камень Фани.
#
# Формат вывода:
# * вещественное число с точностью до 3 цифр после запятой, равное минимаксному расстоянию между камнями Феди и Фани.
# Пример
# ввод:
#
# 3
#
# 17 4
#
# 19 4
#
# 18 5
#
# вывод:
# 1.414

# %%
import sys

count = int(input())
mas = []
for i in range(count):
    mas.append(list(map(int, input().split())))
min = sys.maxsize

for i in mas:
    for j in mas:
        dist = ((i[0] - j[0])**2 + (i[1] - j[1])**2)**0.5
        if dist < min and dist != 0:
            min = dist

print(round(min, 3))
# Out:
#  3
#  17 4
#  19 4
#  18 5
# 1.414

# %% [markdown]
# Ответы на вопросы по статье
#
# 0. Да
# 1. Статья посвящена модифицированному алгоритму Флойда-Уоршелла для случая разреженных и больших графов.
# 2.  Его преимущество заключается в уменьшенном количестве операций релаксации для разреженных графов. Автор предлагает новый метод для повышения эффективности алгоритма Флойда-Уоршелла. Стандартный алгоритм Флойда-Уоршелла, хотя и прост в реализации, выполняет много ненужных операций.
#
# > "Since, the condition of the if statement will not be
#  satisﬁed when either 𝐴[𝑖, 𝑘] or 𝐴[𝑘, 𝑗] is ∞, most of these
#  explorations will be a useless."
#
# 3. Активно пользовался переводчиком :)
# 4. Опечаток обнаружено не было
# 5. В целом, информации достаточно для реализации улучшенного алгоритма Флойда-Уоршелла.
# 6. Существуют ли другие варианты улучшения алгоритма Флойда-Уоршелла?
